# %%
import pandas as pd
import numpy as np
import json

# %%
DATA_DIR = "../data/"
RAW_DATA_DIR = DATA_DIR + "raw.csv"

JSON_DATA_DIR = DATA_DIR + "json/"
TEST_JSON_DATA_DIR = JSON_DATA_DIR + "test_pl.json"

# %%
#standart read csv won't work, commas are in names!!! 
n = 4 #number of columns
df = pd.read_csv(RAW_DATA_DIR,
                 usecols=range(n),
                 lineterminator='\n',
                 header=None)

df = df[1:] #take the data less the header row
df.columns = ["user_id", "artistname", "trackname", "playlistname"] #set the header row as the df header

# %%
df
# Out:
#                                    user_id                        artistname  \
# 1         9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# 2         9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 3         9cc0cfd4d7d7885102480dd99e7a90d6                      Tiffany Page
# 4         9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 5         9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# ...                                    ...                               ...
# 12901975  2302bf9c64dc63d88a750215ed187f2c                       Mötley Crüe
# 12901976  2302bf9c64dc63d88a750215ed187f2c                       John Lennon
# 12901977  2302bf9c64dc63d88a750215ed187f2c                         Tom Petty
# 12901978  2302bf9c64dc63d88a750215ed187f2c                         Tom Petty
# 12901979  2302bf9c64dc63d88a750215ed187f2c                          Skid Row
#
#                                                   trackname    playlistname
# 1                      (The Angels Wanna Wear My) Red Shoes  HARD ROCK 2010
# 2         (What's So Funny 'Bout) Peace, Love And Unders...  HARD ROCK 2010
# 3                                          7 Years Too Late  HARD ROCK 2010
# 4                                     Accidents Will Happen  HARD ROCK 2010
# 5                                                    Alison  HARD ROCK 2010
# ...                                                     ...             ...
# 12901975                                          Wild Side          iPhone
# 12901976                                              Woman          iPhone
# 12901977                        You Don't Know How It Feels          iPhone
# 12901978                                       You Wreck Me          iPhone
# 12901979                                    Youth Gone Wild          iPhone
#
# [12901979 rows x 4 columns]

# %%
pl_gb = df.groupby("playlistname")
test_pl = pl_gb.get_group((list(pl_gb.groups)[1]))
test_pl_name = list(pl_gb.groups)[1]

# %%
display(test_pl_name)
test_pl
# Out:
# '        waves'
#                                    user_id         artistname  \
# 10582172  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582173  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582174  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582175  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582176  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582177  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582178  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582179  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582180  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582181  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582182  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582183  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582184  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582185  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582186  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582187  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582188  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582189  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582190  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582191  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582192  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582193  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582194  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582195  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582196  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582197  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582198  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582199  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582200  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582201  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582202  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582203  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582204  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582205  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582206  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582207  dd413d4343eddb9188394367346ee033  The Wave Pictures
# 10582208  dd413d4343eddb9188394367346ee033  The Wave Pictures
#
#                                                trackname   playlistname
# 10582172                                  All My Friends          waves
# 10582173                                   American Boom          waves
# 10582174                              Better To Be Loved          waves
# 10582175                                     Blind Drunk          waves
# 10582176                            Bye Bye Bubble Belly          waves
# 10582177                                   Cinnamon Baby          waves
# 10582178                                    Coconut Tree          waves
# 10582179                                  Come On Daniel          waves
# 10582180                                     Eskimo Kiss          waves
# 10582181  I Could Hear The Telephone (3 Floors Above Me)          waves
# 10582182                   I Just Want To Be Your Friend          waves
# 10582183                        I Love You Like A Madman          waves
# 10582184                          I Thought Of You Again          waves
# 10582185                           If You Leave It Alone          waves
# 10582186                             Instant Coffee Baby          waves
# 10582187                             Just Like A Drummer          waves
# 10582188                                         Kiss Me          waves
# 10582189                                         Kittens          waves
# 10582190                          Leave The Scene Behind          waves
# 10582191                                          Lisbon          waves
# 10582192                                 Little Surprise          waves
# 10582193                                 Long Black Cars          waves
# 10582194                                         My Kiss          waves
# 10582195                                     Narrow Lane          waves
# 10582196                    Nothing Can Change This Love          waves
# 10582197         Now Your Smile Comes Over In Your Voice          waves
# 10582198                                       Rain Down          waves
# 10582199                                  Red Wine Teeth          waves
# 10582200                                           Shell          waves
# 10582201                                       Spaghetti          waves
# 10582202           Stay Here & Take Care Of The Chickens          waves
# 10582203                               The Easter Parade          waves
# 10582204                       The Lea Bridge Roundabout          waves
# 10582205                                       The Ropes          waves
# 10582206                                          Tropic          waves
# 10582207                            Two Lemons, One Lime          waves
# 10582208                                   We Come Alive          waves

# %%
master_json_list = {}

# %%
test_pl_us = test_pl.user_id.unique()
test_pl_us_cnt = len(test_pl_us)

test_pl_tr = test_pl.trackname.unique()
test_pl_ar = test_pl.artistname.unique()


test_pl_json = {
        #"name": test_pl_name,
        "collaborative": test_pl_us_cnt > 1,
        "num_users": test_pl_us_cnt, 
        "num_edits": len(test_pl), # here for if a song was added twice, check in EDA to see if this actually happens

        "num_tracks": len(test_pl_tr),
        "num_artists": len(test_pl_ar),
        "tracks": list(test_pl_tr),
        "artists": list(test_pl_ar)
}
master_json_list[test_pl_name] = test_pl_json

# %%
master_json_list
# Out:
# {'        waves': {'collaborative': False,
#   'num_users': 1,
#   'num_edits': 37,
#   'num_tracks': 37,
#   'num_artists': 1,
#   'tracks': ['All My Friends',
#    'American Boom',
#    'Better To Be Loved',
#    'Blind Drunk',
#    'Bye Bye Bubble Belly',
#    'Cinnamon Baby',
#    'Coconut Tree',
#    'Come On Daniel',
#    'Eskimo Kiss',
#    'I Could Hear The Telephone (3 Floors Above Me)',
#    'I Just Want To Be Your Friend',
#    'I Love You Like A Madman',
#    'I Thought Of You Again',
#    'If You Leave It Alone',
#    'Instant Coffee Baby',
#    'Just Like A Drummer',
#    'Kiss Me',
#    'Kittens',
#    'Leave The Scene Behind',
#    'Lisbon',
#    'Little Surprise',
#    'Long Black Cars',
#    'My Kiss',
#    'Narrow Lane',
#    'Nothing Can Change This Love',
#    'Now Your Smile Comes Over In Your Voice',
#    'Rain Down',
#    'Red Wine Teeth',
#    'Shell',
#    'Spaghetti',
#    'Stay Here & Take Care Of The Chickens',
#    'The Easter Parade',
#    'The Lea Bridge Roundabout',
#    'The Ropes',
#    'Tropic',
#    'Two Lemons, One Lime',
#    'We Come Alive'],
#   'artists': ['The Wave Pictures']}}

# %%
with open(TEST_JSON_DATA_DIR, "w") as outfile:
    json.dump(master_json_list, outfile)
